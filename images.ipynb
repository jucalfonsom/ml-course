# %% [markdown]
# # Image processing

# %%
# Import libraries

import cv2
from os import scandir, getcwd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Images

# %%
# Images path
path = './data/'

# %%
# Extract files from path
def list_files(path):
    return [arch.name for arch in scandir(path) if arch.is_file()]

# %%
# Print files in path
images = list_files(path)
images
# Out:
# ['NASA.jpg']

# %%
# Get jpg files
for img in images:
    if '.jpg' in img:
        print(img)
# Out:
# NASA.jpg

# %% [markdown]
# ## Video

# %%
# Video path
video1 = './data/video1.mp4'
video2 = './data/video2.mp4'
video_frames = './data/images/'

# %%
# Extract video frames and write in video_frames path
count = 0
cap = cv2.VideoCapture(video1)

while(True):
    reading, frame = cap.read()
    if reading == True:
        cv2.imwrite(video_frames + 'image_%d.jpg' % (count), frame)
    else:
        break
    
    count += 1

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### Reading images

# %%
photo = cv2.imread(video_frames + 'image_0.jpg')
photo.shape
# Out:
# (1080, 1920, 3)

# %%
plt.imshow(photo)

# %% [markdown]
# #### Read only in grayscale
#
# Delete color channels

# %%
# Read in grayscale
photo_gray = cv2.imread(video_frames + 'image_0.jpg', cv2.IMREAD_GRAYSCALE)
photo_gray.shape
# Out:
# (1080, 1920)
